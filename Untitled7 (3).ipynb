# %%
#Name: Devanshi J Patel (UCID: 30186470) Group - 10 
#Individual Milestone

#The code below each cell is serving a purpose as follows please follow the numbering if required,
'''
1) Import data from CSV for Coal, drop columns which are not required.
2) Import data from CSV for Biomass, drop columns which are not required, Fill Nan values with 0.

3) Create Table for Coal dataset
4) Create Table for Biomass dataset

5) Insert data into Coal table
6) Insert data into Biomass table

7) A function that will be used throughout the program to print the reader cursor output for each query.

8) For both Coal and Biomass individually, using regrex find the string pattern and group by CONTINENTS which are NOT INDIVIDUAL COUNTRIES in table, SUM up the electricity generated by the group of continents/ 
non individual countries , followed by sorting them from maximum to minimum geneation. 

9) For both Coal and Biomass individually Using regrex find the string pattern and group by INDIVIDUAL COUNTRIES in table, SUM up the electricity generated by the group of continents/ non individual countries , 
followed by sorting them from maximum to minimum geneation. 

10) For both Coal and Biomass individually from YEAR (2000-2021), using regrex find the string pattern and group by CONTINENTS which are NOT INDIVIDUAL COUNTRIES in table, SUM up the electricity generated by 
the group of continents/ non individual countries , followed by sorting them from maximum to minimum geneation. 

11) For both Coal and Biomass individually from YEAR (2000-2021) , using regrex find the string pattern and group by INDIVIDUAL COUNTRIES in table, SUM up the electricity generated by the group of continents/ 
non individual countries , followed by sorting them from maximum to minimum geneation. 

12) For both Coal and Biomass individually from YEAR (2000-2021) and TOP - 10 with maximum electricity generation, using regrex find the string pattern and group by CONTINENTS which are NOT INDIVIDUAL COUNTRIES 
in table, SUM up the electricity generated by the group of continents/ non individual countries , followed by sorting them from maximum to minimum geneation. 

13) For both Coal and Biomass individually from YEAR (2000-2021) and TOP - 10 with maximum electricity generation, using regrex find the string pattern and group by INDIVIDUAL COUNTRIES in table, SUM up the 
electricity generated by the group of continents/ non individual countries , followed by sorting them from maximum to minimum geneation. 

NOTE: The energy generated is in Terawatt hour (TWh)
'''

# %%
# 1
import mysql.connector
from mysql.connector import errorcode
import pandas as pd

#Importing Coal Dataset
Coal_df = pd.read_csv("Coal_Dataset.csv")
Coal_df.head()

#Dropping Code column from Coal and Biomass dataset as it wont be used for further queries as we have countries and continents names the Code is not required.
Coal_df = Coal_df.drop(['Code'], axis=1)

Coal_df.head()
# Out:
#        Country  Year  TWh
# 0  Afghanistan  2000  0.0
# 1  Afghanistan  2001  0.0
# 2  Afghanistan  2002  0.0
# 3  Afghanistan  2003  0.0
# 4  Afghanistan  2004  0.0

# %%
# 2
import numpy as np
Biomass_df = pd.read_csv("Biomass_Dataset.csv")
#Dropping Code column from Coal and Biomass dataset as it wont be used for further queries as we have countries and continents names the Code is not required.
Biomass_df = Biomass_df.drop(['Code'], axis=1)

#Filling all nan columns with value 0.
Biomass_df = Biomass_df.replace(np.nan, 0)
Biomass_df.head(75)
# Out:
#         Country  Year       TWh
# 0   Afghanistan  2000  0.000000
# 1   Afghanistan  2001  0.000000
# 2   Afghanistan  2002  0.000000
# 3   Afghanistan  2003  0.000000
# 4   Afghanistan  2004  0.000000
# ..          ...   ...       ...
# 70       Africa  2020  8.066416
# 71       Africa  2021  8.026317
# 72       Africa  1965  0.000000
# 73       Africa  1966  0.000000
# 74       Africa  1967  0.000000
#
# [75 rows x 3 columns]

# %%
# 3
import mysql.connector
from mysql.connector import errorcode
import warnings
warnings.filterwarnings('ignore')

myconnection = mysql.connector.connect(user='devanshi_patel1', password='7NTI75GCO',host='datasciencedb.ucalgary.ca', database='devanshi_patel1')

# CREATE TABLE STATEMENT for Electricity generated by Coal
create_statement = '''create table Coal_electricity (
    Country varchar(40) NOT NULL,
    Year int,
    TWh int
    );'''

# now we'll create a cursor and run our create statement
create_cursor = myconnection.cursor()
try:
    create_cursor.execute(create_statement)
except mysql.connector.Error as err:
    if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
        print("Ooops! We already have that table")
    else:
        print("Error Occured!")
else:
    print("table created successfully!")

create_cursor.execute(create_statement)
create_cursor.close()

# %%
# 4
# CREATE TABLE STATEMENT for Electricity generated by Biomass
create_statement = '''create table Biomass_electricity (
    Country varchar(40) NOT NULL,
    Year int,
    TWh int
    );'''

# now we'll create a cursor and run our create statement
create_cursor = myconnection.cursor()
try:
    create_cursor.execute(create_statement)
except mysql.connector.Error as err:
    if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
        print("Ooops! We already have that table")
    else:
        print("Error Occured!")
else:
    print("table created successfully!")

create_cursor.execute(create_statement)
create_cursor.close()

# %%
# 5
#Inserting data into Coal_electricity table
insertCursor = myconnection.cursor()
columnString = "`,`".join([str(currentColumn) for currentColumn in Coal_df.columns.tolist()])

print (columnString)

for i, currentRow in Coal_df.iterrows():
    print (tuple(currentRow))
    insertCommand = "INSERT INTO `Coal_electricity` (`" + columnString + "`) VALUES (" + "%s,"*(len(currentRow)-1) + "%s)"
    print (insertCommand)
    insertCursor.execute(insertCommand, tuple(currentRow))
# inserting rows one by one from the DataFrame is sufficient for now
myconnection.commit()

insertCursor.close()
#6509 rows were inserted

# %%
# 6
#Inserting data into Biomass table
insertCursor = myconnection.cursor()
columnString = "`,`".join([str(currentColumn) for currentColumn in Biomass_df.columns.tolist()])
print (columnString)

for i, currentRow in Biomass_df.iterrows():
    print (tuple(currentRow))
    insertCommand = "INSERT INTO `Biomass_electricity` (`" + columnString + "`) VALUES (" + "%s,"*(len(currentRow)-1) + "%s)"
    print (insertCommand)
    insertCursor.execute(insertCommand, tuple(currentRow))
# inserting rows one by one from the DataFrame is sufficient for now
myconnection.commit()

insertCursor.close()
#9319 rows were inserted

# %%
# 7
#Utility function for printing output depending on the query.
def print_queries(read_cursor):
    for (library_value) in read_cursor:
        print(library_value)

# %%
# 8
#For Coal dataset, Find all the continents and group of countries except individual country names. For Example : World, Asia, Europe are not countires they are either continents or Group of countries.
#Using regex to find out pattern such as Asia% means anything starting with Asia followed by any string.
read_cursor = myconnection.cursor(buffered=True, named_tuple=True)

query_string_only_continents_group_countries = (
"SELECT SUM(TWh) as TWh_Sum, Country FROM Coal_electricity GROUP BY Country HAVING Country like 'Asia%' OR Country LIKE 'Europe%' OR Country LIKE 'South%America%' OR Country LIKE 'North%America%' OR Country LIKE '%(BP)' OR Country LIKE '%countries' OR Country LIKE '%(Ember)' OR Country LIKE 'Oceania' OR Country LIKE 'World' ORDER BY TWh_Sum DESC;")

read_cursor.execute(query_string_only_continents_group_countries)

#Converting output into dataframe for visualization.
columns = [desc[0] for desc in read_cursor.description]
data_df = pd.DataFrame(read_cursor.fetchall(), columns=columns)
print_queries(read_cursor);
read_cursor.close()

data_df.head(10)

import plotly.express as px
fig = px.bar(x=data_df["Country"], y=data_df["TWh_Sum"])
fig.show()

read_cursor.close()
# Out:
# False

# %%
# 8
#For Biomass dataset, Find all the continents and group of countries except individual country names. For Example : World, Asia, Europe are not countires they are either continents or Group of countries.
read_cursor = myconnection.cursor(buffered=True, named_tuple=True)

#Find all the continents and group of countries excepct individual country names.
query_string_only_continents_group_countries = (
"SELECT SUM(TWh) as TWh_Sum, Country FROM Biomass_electricity GROUP BY Country HAVING Country like 'Asia%' OR Country LIKE 'Europe%' OR Country LIKE 'South%America%' OR Country LIKE 'North%America%' OR Country LIKE '%(BP)' OR Country LIKE '%countries' OR Country LIKE '%(Ember)' OR Country LIKE 'Oceania' OR Country LIKE 'World' ORDER BY TWh_Sum DESC;")

read_cursor.execute(query_string_only_continents_group_countries)

#Converting output into dataframe for visualization.
columns = [desc[0] for desc in read_cursor.description]
data_df = pd.DataFrame(read_cursor.fetchall(), columns=columns)
print_queries(read_cursor);
read_cursor.close()

data_df.head(10)

import plotly.express as px
fig = px.bar(x=data_df["Country"], y=data_df["TWh_Sum"])
fig.show()

read_cursor.close()
# Out:
# False

# %%
# 9
#For Coal dataset, Find all the individuaL country names. For Example : China, India, US,Canada and arrange them from highest to lowest production of electricity and group by country. 
#Using the NOT keyword and same pattern with AND instead of OR we get the required result of all individual countries which are not continents and group of countries.

read_cursor = myconnection.cursor(buffered=True, named_tuple=True)

query_string_only_countires = (
"SELECT SUM(TWh) as TWh_Sum, Country FROM Coal_electricity GROUP BY Country HAVING Country NOT like 'Asia%' AND Country NOT LIKE 'Europe%' AND Country NOT LIKE 'South%America%' AND Country NOT LIKE 'North%America%' AND Country NOT LIKE '%(BP)' AND country NOT LIKE '%countries' AND Country NOT LIKE '%(Ember)' AND Country NOT LIKE 'Oceania' AND Country NOT LIKE 'World' ORDER BY TWh_Sum DESC;")
#Find all the individual country names.
read_cursor.execute(query_string_only_countires)

#Converting output into dataframe for visualization.
columns = [desc[0] for desc in read_cursor.description]
data_df = pd.DataFrame(read_cursor.fetchall(), columns=columns)
print_queries(read_cursor);
read_cursor.close()

data_df.head(10)

import plotly.express as px
fig = px.bar(x=data_df["Country"], y=data_df["TWh_Sum"])
fig.show()

read_cursor.close()
# Out:
# False

# %%
# 9
#For Biomass dataset, Find all the individuaL country names. For Example : China, India, US,Canada and arrange them from highest to lowest production of electricity and group by country. 
read_cursor = myconnection.cursor(buffered=True, named_tuple=True)

query_string_only_countires = (
"SELECT SUM(TWh) as TWh_Sum, Country FROM Biomass_electricity GROUP BY Country HAVING Country NOT like 'Asia%' AND Country NOT LIKE 'Europe%' AND Country NOT LIKE 'South%America%' AND Country NOT LIKE 'North%America%' AND Country NOT LIKE '%(BP)' AND country NOT LIKE '%countries' AND Country NOT LIKE '%(Ember)' AND Country NOT LIKE 'Oceania' AND Country NOT LIKE 'World' ORDER BY TWh_Sum DESC;")
#Find all the individual country names.
read_cursor.execute(query_string_only_countires)

#Converting output into dataframe for visualization.
columns = [desc[0] for desc in read_cursor.description]
data_df = pd.DataFrame(read_cursor.fetchall(), columns=columns)
print_queries(read_cursor);
read_cursor.close()

data_df.head(10)

import plotly.express as px
fig = px.bar(x=data_df["Country"], y=data_df["TWh_Sum"])
fig.show()

read_cursor.close()
# Out:
# False

# %%
# 10
#Electricity generation from Coal for a certain period of time(years between 2000 and 2021 normally termed as 20's) for continents and group of countries.
read_cursor = myconnection.cursor(buffered=True, named_tuple=True)

query_string_only_countires_after_2000 = (
"SELECT SUM(TWh) as TWh_Sum, Country FROM Coal_electricity WHERE (Year BETWEEN 2000 AND 2021) GROUP BY Country HAVING Country like 'Asia%' OR Country LIKE 'Europe%' OR Country LIKE 'South%America%' OR Country LIKE 'North%America%' OR Country LIKE '%(BP)' OR Country LIKE '%countries' OR Country LIKE '%(Ember)' OR Country LIKE 'Oceania' OR Country LIKE 'World' ORDER BY TWh_Sum DESC;")
#Find all the individual country names.
read_cursor.execute(query_string_only_countires_after_2000)

#Converting output into dataframe for visualization.
columns = [desc[0] for desc in read_cursor.description]
data_df = pd.DataFrame(read_cursor.fetchall(), columns=columns)
print_queries(read_cursor);
read_cursor.close()

data_df.head(10)

import plotly.express as px
fig = px.bar(x=data_df["Country"], y=data_df["TWh_Sum"])
fig.show()

read_cursor.close()
# Out:
# False

# %%
# 10
#Electricity generation from Biomass for a certain period of time(years between 2000 and 2021 normally termed as 20's) for continents and group of countries.
read_cursor = myconnection.cursor(buffered=True, named_tuple=True)

query_string_only_countires_after_2000 = (
"SELECT SUM(TWh) as TWh_Sum, Country FROM Biomass_electricity WHERE (Year BETWEEN 2000 AND 2021) GROUP BY Country HAVING Country like 'Asia%' OR Country LIKE 'Europe%' OR Country LIKE 'South%America%' OR Country LIKE 'North%America%' OR Country LIKE '%(BP)' OR Country LIKE '%countries' OR Country LIKE '%(Ember)' OR Country LIKE 'Oceania' OR Country LIKE 'World' ORDER BY TWh_Sum DESC;")
#Find all the individual country names.
read_cursor.execute(query_string_only_countires_after_2000)

#Converting output into dataframe for visualization.
columns = [desc[0] for desc in read_cursor.description]
data_df = pd.DataFrame(read_cursor.fetchall(), columns=columns)
print_queries(read_cursor);
read_cursor.close()

data_df.head(10)

import plotly.express as px
fig = px.bar(x=data_df["Country"], y=data_df["TWh_Sum"])
fig.show()

read_cursor.close()
# Out:
# False

# %%
# 11
#Electricity generation from Coal for a certain period of time(years between 2000 and 2021 normally termed as 20's) for individual countires.
read_cursor = myconnection.cursor(buffered=True, named_tuple=True)

query_string_only_countires_after_2000 = (
"SELECT SUM(TWh) as TWh_Sum, Country FROM Coal_electricity WHERE (Year BETWEEN 2000 AND 2021) GROUP BY Country HAVING Country NOT like 'Asia%' AND Country NOT LIKE 'Europe%' AND Country NOT LIKE 'South%America%' AND Country NOT LIKE 'North%America%' AND Country NOT LIKE '%(BP)' AND country NOT LIKE '%countries' AND Country NOT LIKE '%(Ember)' AND Country NOT LIKE 'Oceania' AND Country NOT LIKE 'World' ORDER BY TWh_Sum DESC;")
#Find all the individual country names.
read_cursor.execute(query_string_only_countires_after_2000)
#Converting output into dataframe for visualization.
columns = [desc[0] for desc in read_cursor.description]
data_df = pd.DataFrame(read_cursor.fetchall(), columns=columns)
print_queries(read_cursor);
read_cursor.close()

data_df.head(10)

import plotly.express as px
fig = px.bar(x=data_df["Country"], y=data_df["TWh_Sum"])
fig.show()

read_cursor.close()

#Conclusion: I can observe that China produces almost double amount of electricity than US which stand after China.
# Out:
# False

# %%
# 11
#Electricity generation of Biomass for a certain period of time(years between 2000 and 2021 normally termed as 20's) for individual countires.
read_cursor = myconnection.cursor(buffered=True, named_tuple=True)

query_string_only_countires_after_2000 = (
"SELECT SUM(TWh) as TWh_Sum, Country FROM Biomass_electricity WHERE (Year BETWEEN 2000 AND 2021) GROUP BY Country HAVING Country NOT like 'Asia%' AND Country NOT LIKE 'Europe%' AND Country NOT LIKE 'South%America%' AND Country NOT LIKE 'North%America%' AND Country NOT LIKE '%(BP)' AND country NOT LIKE '%countries' AND Country NOT LIKE '%(Ember)' AND Country NOT LIKE 'Oceania' AND Country NOT LIKE 'World' ORDER BY TWh_Sum DESC;")
#Find all the individual country names.
read_cursor.execute(query_string_only_countires_after_2000)

#Converting output into dataframe for visualization.
columns = [desc[0] for desc in read_cursor.description]
data_df = pd.DataFrame(read_cursor.fetchall(), columns=columns)
print_queries(read_cursor);
read_cursor.close()

data_df.head(10)

import plotly.express as px
fig = px.bar(x=data_df["Country"], y=data_df["TWh_Sum"])
fig.show()

read_cursor.close()
# Out:
# False

# %%
# 12
#Electricity generation from Coal for a certain period of time(years between 2000 and 2021 normally termed as 20's) for each continent or group of countries only top 10.
read_cursor = myconnection.cursor(buffered=True, named_tuple=True)

#Find all the continents and group of countries excepct individual country names.
query_string_only_continents_group_countries_after_2000 = (
"SELECT SUM(TWh) as TWh_Sum, Country FROM Coal_electricity GROUP BY Country HAVING Country like 'Asia%' OR Country LIKE 'Europe%' OR Country LIKE 'South%America%' OR Country LIKE 'North%America%' OR Country LIKE '%(BP)' OR Country LIKE '%countries' OR Country LIKE '%(Ember)' OR Country LIKE 'Oceania' OR Country LIKE 'World' ORDER BY TWh_Sum DESC LIMIT 10;")

read_cursor.execute(query_string_only_continents_group_countries_after_2000)
#Converting output into dataframe for visualization.
columns = [desc[0] for desc in read_cursor.description]
data_df = pd.DataFrame(read_cursor.fetchall(), columns=columns)
print_queries(read_cursor);
read_cursor.close()

data_df.head(10)

import plotly.express as px
fig = px.bar(x=data_df["Country"], y=data_df["TWh_Sum"])
fig.show()

read_cursor.close()

#Conclusion: From 2000- 2021 , continent wise Asia has highest generation of electricity by Coal.
# Out:
# False

# %%
# 12
#Electricity generation from Biomass for a certain period of time(years between 2000 and 2021 normally termed as 20's) for each continent or group of countries only top 10.
read_cursor = myconnection.cursor(buffered=True, named_tuple=True)

#Find all the continents and group of countries excepct individual country names.
query_string_only_continents_group_countries_after_2000 = (
"SELECT SUM(TWh) as TWh_Sum, Country FROM Biomass_electricity GROUP BY Country HAVING Country like 'Asia%' OR Country LIKE 'Europe%' OR Country LIKE 'South%America%' OR Country LIKE 'North%America%' OR Country LIKE '%(BP)' OR Country LIKE '%countries' OR Country LIKE '%(Ember)' OR Country LIKE 'Oceania' OR Country LIKE 'World' ORDER BY TWh_Sum DESC LIMIT 10;")

read_cursor.execute(query_string_only_continents_group_countries_after_2000)

#Converting output into dataframe for visualization.
columns = [desc[0] for desc in read_cursor.description]
data_df = pd.DataFrame(read_cursor.fetchall(), columns=columns)
print_queries(read_cursor);
read_cursor.close()

data_df.head(10)

import plotly.express as px
fig = px.bar(x=data_df["Country"], y=data_df["TWh_Sum"])
fig.show()

read_cursor.close()

#Conclusion: From 2000- 2021 , continent wise Europe has highest generation of electricity by biomass.
# Out:
# False

# %%
# 13
#Electricity generation from Coal for a certain period of time(years between 2000 and 2021 normally termed as 20's) for individual countires only top 10.
read_cursor = myconnection.cursor(buffered=True, named_tuple=True)

query_string_only_countires_after_2000 = (
"SELECT SUM(TWh) as TWh_Sum, Country FROM Coal_electricity WHERE (Year BETWEEN 2000 AND 2021) GROUP BY Country HAVING Country NOT like 'Asia%' AND Country NOT LIKE 'Europe%' AND Country NOT LIKE 'South%America%' AND Country NOT LIKE 'North%America%' AND Country NOT LIKE '%(BP)' AND country NOT LIKE '%countries' AND Country NOT LIKE '%(Ember)' AND Country NOT LIKE 'Oceania' AND Country NOT LIKE 'World' ORDER BY TWh_Sum DESC LIMIT 10;")
#Find all the individual country names.
read_cursor.execute(query_string_only_countires_after_2000)

#Converting output into dataframe for visualization.
columns = [desc[0] for desc in read_cursor.description]
data_df = pd.DataFrame(read_cursor.fetchall(), columns=columns)
print_queries(read_cursor);
read_cursor.close()

data_df.head(10)

import plotly.express as px
fig = px.bar(x=data_df["Country"], y=data_df["TWh_Sum"])
fig.show()

read_cursor.close()

#Conclusion: Unites states and China has maximum electricity generation thus maximum Coal is used for generation in this countries.
# Out:
# False

# %%
# 13
#Electricity generation from Biomass for a certain period of time(years between 2000 and 2021 normally termed as 20's) for individual countires only top 10.
read_cursor = myconnection.cursor(buffered=True, named_tuple=True)

query_string_only_countires_after_2000 = (
"SELECT SUM(TWh) as TWh_Sum, Country FROM Biomass_electricity WHERE (Year BETWEEN 2000 AND 2021) GROUP BY Country HAVING Country NOT like 'Asia%' AND Country NOT LIKE 'Europe%' AND Country NOT LIKE 'South%America%' AND Country NOT LIKE 'North%America%' AND Country NOT LIKE '%(BP)' AND country NOT LIKE '%countries' AND Country NOT LIKE '%(Ember)' AND Country NOT LIKE 'Oceania' AND Country NOT LIKE 'World' ORDER BY TWh_Sum DESC LIMIT 10;")
#Find all the individual country names.
read_cursor.execute(query_string_only_countires_after_2000)

#Converting output into dataframe for visualization.
columns = [desc[0] for desc in read_cursor.description]
data_df = pd.DataFrame(read_cursor.fetchall(), columns=columns)
print_queries(read_cursor);
read_cursor.close()

data_df.head(10)

import plotly.express as px
fig = px.bar(x=data_df["Country"], y=data_df["TWh_Sum"])
fig.show()

read_cursor.close()

#Conclusion: Unites states and China has maximum electricity generation thus maximum Biomass is used for generation in this countries.
# Out:
# False

# %%
'''
Works Cited & Bibliography 
(Coal), O. W. i. D., 2021. https://ourworldindata.org. [Online] 
Available at: https://ourworldindata.org/grapher/electricity-coal
[Accessed 25 November 2022].
(Hydro), O. W. i. D., 2021. https://ourworldindata.org. [Online] 
Available at: https://ourworldindata.org/grapher/hydropower-consumption
[Accessed 25 November 2022].
(Nuclear), O. W. i. D., 2021. https://ourworldindata.org. [Online] 
Available at: https://ourworldindata.org/grapher/nuclear-energy-generation?tab=table&country=~OWID_WRL
[Accessed 25 November 2022].
(Oil), O. W. i. D., 2021. https://ourworldindata.org. [Online] 
Available at: https://ourworldindata.org/grapher/electricity-oil?tab=table
[Accessed 25 November 2022].
(Solar), O. W. i. D., 2021. https://ourworldindata.org. [Online] 
Available at: https://ourworldindata.org/grapher/solar-energy-consumption?tab=table
[Accessed 25 November 2022].
(Wind), O. W. i. D., 2021. https://ourworldindata.org. [Online] 
Available at: https://ourworldindata.org/grapher/wind-generation?tab=table
[Accessed 25 November 2022].
Administration, U. E. I. (., April 2022. U.S. energy consumption by source and sector, 2021. [Online] 
Available at: https://www.eia.gov/totalenergy/data/monthly/pdf/flow/total-energy-spaghettichart-2021.pdf
[Accessed 25 November 2022].
BP, 2022. bp.com. [Online] 
Available at: https://www.bp.com/content/dam/bp/business-sites/en/global/corporate/pdfs/energy-economics/statistical-review/bp-stats-review-2022-methodology.pdf
[Accessed 20 November 2022].
Canada, G. o., 2022. Zero Emission Vehicle Infrastructure Program. [Online] 
Available at: https://www.nrcan.gc.ca/energy-efficiency/transportation-alternative-fuels/zero-emission-vehicle-infrastructure-program/21876
[Accessed 4 November 2022].
Data, O. W. i., 2022. ourworldindata.org. [Online] 
Available at: https://ourworldindata.org
[Accessed 23 November 2022].
Ember, 2022. Ember-climate.org. [Online] 
Available at: https://ember-climate.org/app/uploads/2022/03/GER22-Methodology.pdf
[Accessed 25 November 2022].
Ember, 2022. Ember-climate.org. [Online] 
Available at: https://ember-climate.org/app/uploads/2022/02/EER-Methodology.pdf
[Accessed 5 November 2022].
Gas), O. W. i. D. (., 2021. https://ourworldindata.org. [Online] 
Available at: https://ourworldindata.org/grapher/electricity-gas
[Accessed 21 November 2022].
IPCC, 2020. ipcc.ch. [Online] 
Available at: www.ipcc.ch/sr15/
[Accessed 25 November 2022].
NASA, 2019. Climate NASA. [Online] 
Available at: https://climate.nasa.gov/news/2865/a-degree-of-concern-why-global-temperatures-matter/
[Accessed 25 November 2022].
NASA, 2022. NASA Earth Observatory. [Online] 
Available at: https://earthobservatory.nasa.gov/world-of-change/global-temperatures
[Accessed 25 November 2022].
UN, 2021. www.un.org. [Online] 
Available at: https://www.un.org/en/climatechange/net-zero-coalition
[Accessed 25 November 2022].

'''
